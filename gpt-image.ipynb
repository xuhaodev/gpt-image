# %%
# add local module support and simplified image display
import os, sys
sys.path.append(os.getcwd())
from IPython.display import display, Image as DispImage
from azure_gpt_image import generate_image, edit_image

# generate
path = generate_image("画一个吉卜力风格的画，一只棕色的狗骑着一辆黄色的本田幼兽CC110", size="1024x1536", out_path="new_image.png")

# simplified display
display(DispImage(filename=path))

# %%
# edit
edited = edit_image("generated_image.png", "将摩托车改为白色，其它保持不变")

# simplified display
display(DispImage(filename=edited))
